# %%
from backend.tools import convert_mp4_to_gif
convert_mp4_to_gif("mp4/plan_plot.mp4", "converted/plot.gif", 3)
# Out:
# ffmpeg version N-115034-ge09164940e-tessus  https://evermeet.cx/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
# ...

# %%
from backend.tools import change_mp4_speed
change_mp4_speed("mp4/plan_plot.mp4", "mp4/plan_plot_speed.mp4", 3)
# Out:
# ffmpeg version N-115034-ge09164940e-tessus  https://evermeet.cx/ffmpeg/  Copyright (c) 2000-2024 the FFmpeg developers
#   built with Apple clang version 15.0.0 (clang-1500.3.9.4)
# ...

# %%
from backend.tools import PDFMerger
save_dir = "/Users/danliu/job_application"  
merger = PDFMerger(save_dir=save_dir, input_dir = save_dir)

output_filename = "merged_output_3"  
merger.merge_from_folder(output_filename)

output_filename = "merged_output_4" 
merger.merge_specific_files_from_folder(["Resume", "masters"],
                                        output_filename)
# Out:
# Merged file saved at path /Users/danliu/job_application/merged_output_3.pdf
# Merged file saved at path /Users/danliu/job_application/merged_output_4.pdf
